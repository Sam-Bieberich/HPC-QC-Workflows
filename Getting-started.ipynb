# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import qiskit.tools.jupyter
# ----> 2 get_ipython().run_line_magic('qiskit_version_table', '')
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2305, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2303     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2304 with self.builtin_trap:
# -> 2305     result = fn(*args, **kwargs)
#    2306 return result
#
# File ~/.local/lib/python3.9/site-packages/qiskit/tools/jupyter/version_table.py:41, in VersionTable.qiskit_version_table(self, line, cell)
#      38 packages = []
#      39 qver = qiskit.__qiskit_version__
# ---> 41 for pkg in qver:
#      42     if qver[pkg]:
#      43         packages.append((f"<code>{pkg}</code>", qver[pkg]))
#
# File ~/.local/lib/python3.9/site-packages/qiskit/version.py:180, in QiskitVersion.__iter__(self)
#     178 def __iter__(self):
#     179     if not self._loaded:
# --> 180         self._load_versions()
#     181     return iter(self._version_dict)
#
# File ~/.local/lib/python3.9/site-packages/qiskit/version.py:146, in QiskitVersion._load_versions(self)
#     144     self._version_dict["qiskit-finance"] = None
#     145 try:
# --> 146     import qiskit_optimization
#     148     self._version_dict["qiskit-optimization"] = qiskit_optimization.__version__
#     149 except Exception:
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/qiskit_optimization/__init__.py:90, in <module>
#      88 from .infinity import INFINITY  # must be at the top of the file
#      89 from .exceptions import QiskitOptimizationError
# ---> 90 from .problems.quadratic_program import QuadraticProgram
#      92 __all__ = ["__version__", "QuadraticProgram", "QiskitOptimizationError", "INFINITY"]
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/qiskit_optimization/problems/__init__.py:49, in <module>
#      47 from .quadratic_expression import QuadraticExpression
#      48 from .quadratic_objective import QuadraticObjective
# ---> 49 from .quadratic_program import QuadraticProgram
#      50 from .quadratic_program_element import QuadraticProgramElement
#      51 from .variable import Variable, VarType
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/qiskit_optimization/problems/quadratic_program.py:22, in <module>
#      19 from typing import Dict, List, Optional, Tuple, Union, cast
#      21 import numpy as np
# ---> 22 from docplex.mp.model_reader import ModelReader
#      23 from numpy import ndarray
#      24 from scipy.sparse import spmatrix
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/docplex/mp/model_reader.py:11, in <module>
#       8 import time
#      10 # docplex
# ---> 11 from docplex.mp.model import Model
#      12 from docplex.mp.utils import DOcplexException, MockIterable
#      13 from docplex.mp.environment import Environment
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/docplex/mp/model.py:14, in <module>
#      11 from itertools import chain
#      12 from io import StringIO
# ---> 14 from docplex.mp.aggregator import ModelAggregator
#      15 from docplex.mp.constants import SOSType, CplexScope, ObjectiveSense, BasisStatus, EffortLevel,\
#      16     int_probtype_to_string, ComparisonType
#      17 from docplex.mp.constr import AbstractConstraint, LinearConstraint, RangeConstraint, \
#      18     IndicatorConstraint, QuadraticConstraint, PwlConstraint, EquivalenceConstraint
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/docplex/mp/aggregator.py:11, in <module>
#       1 # --------------------------------------------------------------------------
#       2 # Source file provided under Apache License, Version 2.0, January 2004,
#       3 # http://www.apache.org/licenses/
#    (...)
#       6
#       7 # gendoc: ignore
#       9 from docplex.mp.xcounter import update_dict_from_item_value
# ---> 11 from docplex.mp.utils import is_number, is_iterable, is_iterator, is_pandas_series, \
#      12     is_numpy_ndarray, is_pandas_dataframe, is_numpy_matrix, is_ordered_sequence
#      13 from docplex.mp.linear import MonomialExpr, AbstractLinearExpr, LinearExpr, ZeroExpr
#      14 from docplex.mp.dvar import Var
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/docplex/mp/utils.py:75, in <module>
#      72     numpy_is_integer = None
#      74 try:
# ---> 75     from pandas import Series, DataFrame
#      77     __pandas_series_type = Series
#      78     __pandas_dataframe_type = DataFrame
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/__init__.py:22, in <module>
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import (
#      23     np_version_under1p18 as _np_version_under1p18,
#      24     is_numpy_dev as _is_numpy_dev,
#      25 )
#      27 try:
#      28     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/compat/__init__.py:15, in <module>
#      12 import warnings
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_array_datetime64_compat,
#      18     np_datetime64_compat,
#      19     np_version_under1p18,
#      20     np_version_under1p19,
#      21     np_version_under1p20,
#      22 )
#      23 from pandas.compat.pyarrow import (
#      24     pa_version_under1p0,
#      25     pa_version_under2p0,
#      26     pa_version_under3p0,
#      27     pa_version_under4p0,
#      28 )
#      30 PY38 = sys.version_info >= (3, 8)
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/compat/numpy/__init__.py:7, in <module>
#       3 import re
#       5 import numpy as np
# ----> 7 from pandas.util.version import Version
#       9 # numpy versioning
#      10 _np_version = np.__version__
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/util/__init__.py:1, in <module>
# ----> 1 from pandas.util._decorators import (  # noqa
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#       7 from pandas.core.util.hashing import (  # noqa
#       8     hash_array,
#       9     hash_pandas_object,
#      10 )
#      13 def __getattr__(name):
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/util/_decorators.py:14, in <module>
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa
#      15 from pandas._typing import F
#      18 def deprecate(
#      19     name: str,
#      20     alternative: Callable[..., Any],
#    (...)
#      25     msg: str | None = None,
#      26 ) -> Callable[[F], F]:
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/_libs/__init__.py:13, in <module>
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/_libs/tslibs/__init__.py:31, in <module>
#       1 __all__ = [
#       2     "dtypes",
#       3     "localize_pydatetime",
#    (...)
#      27     "tz_compare",
#      28 ]
#      30 from pandas._libs.tslibs import dtypes
# ---> 31 from pandas._libs.tslibs.conversion import (
#      32     OutOfBoundsTimedelta,
#      33     localize_pydatetime,
#      34 )
#      35 from pandas._libs.tslibs.dtypes import Resolution
#      36 from pandas._libs.tslibs.nattype import (
#      37     NaT,
#      38     NaTType,
#    (...)
#      41     nat_strings,
#      42 )
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:1, in init pandas._libs.tslibs.conversion()
#
# File ~/opt/anaconda3/envs/qiskit-stable/lib/python3.9/site-packages/pandas/_libs/tslibs/tzconversion.pyx:1, in init pandas._libs.tslibs.tzconversion()
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:

# %%
from qiskit import IBMQ, QuantumCircuit, transpile
from qiskit.tools import job_monitor
from qiskit.visualization import plot_histogram, plot_gate_map

# %%
# Loading your IBM Quantum account(s)
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
provider.backends()
backend = provider.get_backend('ibmq_santiago')
#plot_gate_map('ibmq_santiago')

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()
qc.draw(output='mpl')

# %%
import qiskit.tools.jupyter
# %qiskit_job_watcher
# Out:
# Accordion(children=(VBox(layout=Layout(max_width='710px', min_width='710px')),), layout=Layout(max_height='500…

# %%
# run job on hardware
job = backend.run(transpile(qc, backend=backend), shots=1024)
print(job.job_id())
job_monitor(job)
# Out:
# 62a899ab186526c00e919d34
# Job Status: job has successfully run

# %%
#retrieve previously-run job
job = backend.retrieve_job('62a899ab186526c00e919d34')

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
plot_histogram(job.result().get_counts())
